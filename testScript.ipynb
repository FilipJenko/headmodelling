# %%
#matplotlib widget is used for 3D spinning the scatter plot, it can be turned off but you can only display as 2D plots then
# %matplotlib widget

import functionsFinal as f
import pathlib
import numpy as np

# %%
#scan processing

#color masks
yHueCenter=0.14
yHueWidth=0.035
ySatCenter=0.65
ySatWidth=0.35
yValueCenter=0.8
yValueWidth=0.3

bHueCenter=0.35
bHueWidth=0.1
bSatCenter=0.45
bSatWidth=0.35
bValueCenter=0.45
bValueWidth=0.15
masks=np.array([yHueCenter, yHueWidth, ySatCenter, ySatWidth, yValueCenter, yValueWidth, bHueCenter, bHueWidth, bSatCenter, bSatWidth, bValueCenter, bValueWidth])

#function inputs
path=pathlib.Path().resolve()
numSor=31
numDet=30
numElYellow=61
numElBlue=6
radius=6.5
radiusBlue=5
myPath=pathlib.Path().resolve()
optSizeYellow=22.6
optSizeBlue=0
distance2Plane=2
twoPoints="Iz"
#read and write files
readFileScan="scan/scan2post"
readFileOptodes="Standard_Optodes.txt"
readFileClustersBlue="scan/pointsBlue{num}.ply".format(num={})
readFileClustersYellow="scan/pointsYellow{num}.ply".format(num={})
readFilePlaneBlue="scan/normals(+d)Blue{num}.csv".format(num={})
readFilePlaneYellow="scan/normals(+d)Yellow{num}.csv".format(num={})
writeFile="coordsTest.txt"

orderedYellow, orderedBlue, errLabels=f.processOne(readFileScan, readFileOptodes, readFileClustersBlue, readFileClustersYellow, readFilePlaneBlue,  readFilePlaneYellow, writeFile, masks, numSor, numDet, numElYellow, numElBlue, radius, radiusBlue, myPath, 
optSizeYellow, optSizeBlue, distance2Plane, twoPoints, printErr=True, plot=True, idxArr=[], incorrectRecognition=False, splitFirst=False)
#21s-35s
# Out:
# 8.201313058182436 4.006881612312703
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
